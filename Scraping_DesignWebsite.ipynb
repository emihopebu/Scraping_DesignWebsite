# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - Request & CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': '5d643650-0e6f-4b98-af37-4d5a55b10117',
    'sec-ch-ua-mobile': '?1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Mobile Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cookie': 'gk_suid=14598511; gki=^%^7B^%^22feature_stock_rail^%^22^%^3Afalse^%^2C^%^22feature_stock_row_featured^%^22^%^3Afalse^%^7D; bcp=5d643650-0e6f-4b98-af37-4d5a55b10117; gpv=behance.net:search:projects; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; OptanonChoice=1; s_cc=true; s_sq=^%^5B^%^5BB^%^5D^%^5D; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C18848189015851806872338781647343674484^%^7CMCAAMLH-1633452125^%^7C4^%^7CMCAAMB-1633452125^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1632854525s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-1075503989^%^7CvVersion^%^7C5.0.0; sign_up_prompt=true; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C4248^%^2C1328^%^2C1140^%^2C1328^%^2C1140^%^2C2^%^2C^%^22P^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Tue+Sep+28+2021+11^%^3A47^%^3A39+GMT-0500+(Colombia+Standard+Time)&version=6.9.0&hosts=&consentId=aab74e15-9637-4035-8d26-fc68065e220c&interactionCount=1&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&AwaitingReconsent=false; dialog_dismissals=push_to_mobile_prompt',
    'if-modified-since': 'Tue, 28 Sep 2021 16:42:35 +0000',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json=response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
#result items (total:48)
result_items=results_json['search']['content']['projects']

# %%
len(result_items)
# Out:
# 48

# %%
result_items[0]
# Out:
# {'id': 127930711,
#  'name': 'Remy Architects | Visual Identity',
#  'published_on': 1632753660,
#  'created_on': 1632356048,
#  'modified_on': 1632850211,
#  'url': 'https://www.behance.net/gallery/127930711/Remy-Architects-Visual-Identity',
#  'slug': 'Remy-Architects-Visual-Identity',
#  'privacy': 'public',
#  'fields': ['Graphic Design', 'Photography', 'Architecture'],
#  'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
# ...

# %%
#name
#first name
#last name
#user name
#country
#views
#appreciations
#comments
#url

# %%
result_items[0]
# Out:
# {'id': 127930711,
#  'name': 'Remy Architects | Visual Identity',
#  'published_on': 1632753660,
#  'created_on': 1632356048,
#  'modified_on': 1632850211,
#  'url': 'https://www.behance.net/gallery/127930711/Remy-Architects-Visual-Identity',
#  'slug': 'Remy-Architects-Visual-Identity',
#  'privacy': 'public',
#  'fields': ['Graphic Design', 'Photography', 'Architecture'],
#  'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
#   '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/e240e4127930711.Y3JvcCwxMTg2LDkyOCwwLDA.jpg',
# ...

# %%
#name
result_items[0]['name']
# Out:
# 'Remy Architects | Visual Identity'

# %%
#first name
result_items[0]['owners'][0]['first_name']
# Out:
# 'Julia'

# %%
#last name
result_items[0]['owners'][0]['last_name']
# Out:
# 'Miceli Pitta'

# %%
#username
result_items[0]['owners'][0]['username']
# Out:
# 'juliamiceli'

# %%
#country
result_items[0]['owners'][0]['country']
# Out:
# 'United Kingdom'

# %%
#views
result_items[0]['stats']['views']
# Out:
# 608

# %%
#appreciations
result_items[0]['stats']['appreciations']
# Out:
# 148

# %%
#comments
result_items[0]['stats']['comments']
# Out:
# 19

# %%
 #url
result_items[0]['url']
# Out:
# 'https://www.behance.net/gallery/127930711/Remy-Architects-Visual-Identity'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
url=[]
comments=[]
name=[]
first_name=[]
last_name=[]
appreciations=[]
views=[]
country=[]
username=[]

for result in result_items:
    #name
    
    name.append(result['name'])
    
    #first name
    first_name.append(result['owners'][0]['first_name'])
    
    #last name
    last_name.append(result['owners'][0]['last_name'])
    
    #username
    username.append(result['owners'][0]['username'])
    
    #country
    country.append(result['owners'][0]['country'])
    
    #views
    views.append(result['stats']['views'])
    
    #appreciations
    appreciations.append(result['stats']['appreciations'])
    
    #comments
    comments.append(result['stats']['comments'])
    
    #url
    url.append(result['url'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
#name
#first name
#last name
#user name
#country
#views
#appreciations
#comments
#url
df=pd.DataFrame({'Name':name,'First Name':first_name,'Last name':last_name,
                'Username':username,'Country':country,'Views':views,'Appreciations':appreciations,'Comments':comments,'URL':url})

# %%
df
# Out:
#                                                  Name        First Name  \
# 0                   Remy Architects | Visual Identity             Julia
# 1              Vaugirard Residence I- Interior Design             Mirna
# 2                                         A N G L E S           Nicolas
# 3                           URBAN GEOMETRY // SEOUL V            Andrés
# 4                                 Villa in the fields          KATARSIS
# 5    Ri_Tagli by Terzo Piano for La Pietra Compattata             TERZO
# 6               Globeplants bundle 11 : Desert Garden       Nguyen Ngoc
# 7                                Marks compilation 01                d.
# 8                                        Hong Kong II               Tom
# 9            Big Family House by studio Archispektras          Vaidotas
# 10                                       RB APARTMENT           Natalia
# 11                                            MINIMOD            Studio
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 10 pages to get 480 results)

# %%
headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': '5d643650-0e6f-4b98-af37-4d5a55b10117',
    'sec-ch-ua-mobile': '?1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Mobile Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cookie': 'gk_suid=14598511; gki=^%^7B^%^22feature_stock_rail^%^22^%^3Afalse^%^2C^%^22feature_stock_row_featured^%^22^%^3Afalse^%^7D; bcp=5d643650-0e6f-4b98-af37-4d5a55b10117; gpv=behance.net:search:projects; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; OptanonChoice=1; s_cc=true; s_sq=^%^5B^%^5BB^%^5D^%^5D; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C18848189015851806872338781647343674484^%^7CMCAAMLH-1633452125^%^7C4^%^7CMCAAMB-1633452125^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1632854525s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-1075503989^%^7CvVersion^%^7C5.0.0; sign_up_prompt=true; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C4248^%^2C1328^%^2C1140^%^2C1328^%^2C1140^%^2C2^%^2C^%^22P^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Tue+Sep+28+2021+11^%^3A47^%^3A39+GMT-0500+(Colombia+Standard+Time)&version=6.9.0&hosts=&consentId=aab74e15-9637-4035-8d26-fc68065e220c&interactionCount=1&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&AwaitingReconsent=false; dialog_dismissals=push_to_mobile_prompt',
    'if-modified-since': 'Tue, 28 Sep 2021 16:42:35 +0000',
}

url=[]
comments=[]
name=[]
first_name=[]
last_name=[]
appreciations=[]
views=[]
country=[]
username=[]

#scrape 10 pages

for i in range(0,480,48):
    params = (
        ('content', 'projects'),
        ('field', 'architecture'),
        ('ordinal', str(i)),
    )
    
    #response variable with request

    response = requests.get('https://www.behance.net/search', headers=headers, params=params)
    
    #json object
    results_json=response.json()
    
    #result items
    result_items=results_json['search']['content']['projects']
    for result in result_items:
        #name

        name.append(result['name'])

        #first name
        first_name.append(result['owners'][0]['first_name'])

        #last name
        last_name.append(result['owners'][0]['last_name'])

        #username
        username.append(result['owners'][0]['username'])

        #country
        country.append(result['owners'][0]['country'])

        #views
        views.append(result['stats']['views'])

        #appreciations
        appreciations.append(result['stats']['appreciations'])

        #comments
        comments.append(result['stats']['comments'])

        #url
        url.append(result['url'])

# %%
df=pd.DataFrame({'Name':name,'First Name':first_name,'Last name':last_name,
                'Username':username,'Country':country,'Views':views,'Appreciations':appreciations,'Comments':comments,'URL':url})

# %%
df
# Out:
#                                                 Name First Name  \
# 0                  Remy Architects | Visual Identity      Julia
# 1             Vaugirard Residence I- Interior Design      Mirna
# 2                                        A N G L E S    Nicolas
# 3                          URBAN GEOMETRY // SEOUL V     Andrés
# 4                                Villa in the fields   KATARSIS
# ..                                               ...        ...
# 475                                     Comfort City      Hanna
# 476                    Saint Petersburg Architecture    Kamilla
# 477  Exhibition Center | Architectural Visualization    DOF.one
# 478                      THE PHARAOH'S GOLDEN PARADE      RAMI
# 479                           Lamborghini SIAN (CGI)   Vladimir
#
#             Last name         Username             Country  Views  \
# 0        Miceli Pitta      juliamiceli      United Kingdom    706
# ...

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
df.to_excel('pictures_multiple_pages.xlsx', index=False)
